# %%
import pandas as pd
import random
from multiprocessing import Pool

bi214 = pd.read_csv('bi214_data.csv')
po214 = pd.read_csv('po214_data.csv')
cf252 = pd.read_csv('cf252_data.csv')
na22 = pd.read_csv('na22_data.csv')

total = pd.concat([bi214,po214,cf252,na22],ignore_index=True)

# %%
def cut_1D(min,max):
    
    #print(min)
    #print(max)
    cut = df[df['{}'.format(datatype)].between(min, max)]
    totalcut = total[total['{}'.format(datatype)].between(min, max)]
    
    signal = len(cut)
    background = len(totalcut)
    #print(background)
    
    confidence = signal/(background+0.0001)
    countscovered = signal/len(df.pulseArea_phd)
    
    perf = confidence + countscovered
    
    return perf - 2

def cut_3D(xmin,xmax,ymin,ymax,zmin,zmax):
    cut1 = df[df['pulseArea_phd'].between(xmin, xmax)]
    cut2 = cut1[cut1['af75pa'].between(ymin,ymax)] 
    cutted = cut2[cut2['pulselength'].between(zmin,zmax)]
    
    totalcut1 = total[total['pulseArea_phd'].between(xmin, xmax)]
    totalcut2 = totalcut1[totalcut1['af75pa'].between(ymin,ymax)]
    totalcutted = totalcut2[totalcut2['pulselength'].between(zmin,zmax)]
    
    signal = len(cutted)
    background = len(totalcutted)
    
    confidence = signal/(background+0.0001)
    countscovered = signal/len(df.pulseArea_phd)
    
    perf = confidence + countscovered
    
    return perf -2

# %%
df = bi214
datatype = 'pulseArea_phd'
cut_1D(0,1000)
# Out:
# -0.7341362673820848

# %%
def fitness(min,max):
    ans = cut_1D(min,max)
    
    if ans == 0:
        return 99999
    else:
        return abs(1/ans)

def solutions():
        #Generate solutions
        solutions = []
        for s in range(10000):
            start = random.uniform(0,800)
            solutions.append(  (start, random.uniform(start,5))  )
    
        #print(solutions[:5])

        for i in range(200):
    
            rankedsolutions = []
            for s in solutions:
                rankedsolutions.append( (fitness(s[0],s[1]),s) )
            rankedsolutions.sort()
            rankedsolutions.reverse()
            
        if i == 199:
            print(f"=== Gen {i} best solutions ===")
            print(rankedsolutions[0])
                
            
    
            bestsolutions = rankedsolutions[:100]
            elements =[]
            for s in bestsolutions:
                elements.append(s[1][0])
                elements.append(s[1][1])
            newgen = []
            for _ in range(1000):
                e1 = random.choice(elements) * random.uniform(0.99,1.01)
                e2 = random.choice(elements) * random.uniform(0.99,1.01)
        
                newgen.append((e1,e2))
        
            solutions = newgen

# %%
def fitness3D(xmin,xmax,ymin,ymax,zmin,zmax):
    ans = cut_3D(xmin,xmax,ymin,ymax,zmin,zmax)
    
    if ans == 0:
        return 99999
    else:
        return abs(1/ans)

def solutions3D():
        #Generate solutions
        solutions = []
        for s in range(1000):
            xmin = random.uniform(0,800)
            ymin = random.uniform(0,20)
            zmin = random.uniform(0,800)
            solutions.append(  (xmin, random.uniform(xmin,800), ymin, random.uniform(ymin,20), zmin, random.uniform(zmin,800) )  )
    
        #print(solutions[:5])

        for i in range(1000):
    
            rankedsolutions = []
            for s in solutions:
                rankedsolutions.append( (fitness3D(s[0], s[1], s[2], s[3], s[4], s[5]),s))
            rankedsolutions.sort()
            rankedsolutions.reverse()
            
            #if i == 99:
            print(f"=== Gen {i} best solutions ===")
            print(rankedsolutions[0])
                
            
    
            bestsolutions = rankedsolutions[:100]
            elements =[]
            for s in bestsolutions:
                elements.append(s[1][0])
                elements.append(s[1][1])
                elements.append(s[1][2])
                elements.append(s[1][3])
                elements.append(s[1][4])
                elements.append(s[1][5])
                
            newgen = []
            for _ in range(1000):
                e1 = random.choice(elements) * random.uniform(0.99,1.01)
                e2 = random.choice(elements) * random.uniform(0.99,1.01)
                e3 = random.choice(elements) * random.uniform(0.99,1.01)
                e4 = random.choice(elements) * random.uniform(0.99,1.01)
                e5 = random.choice(elements) * random.uniform(0.99,1.01)
                e6 = random.choice(elements) * random.uniform(0.99,1.01)
                
                newgen.append((e1,e2,e3,e4,e5,e6))
        
            solutions = newgen

# %%
df = bi214
datatype = 'pulseArea_phd'
solutions()
'''
df = po214
datatype = 'pulseArea_phd'
solutions()
df = cf252
datatype = 'pulseArea_phd'
solutions()
df = na22
datatype = 'pulseArea_phd'
solutions()
df = bi212
datatype = 'pulselength'
solutions()
df = po214
datatype = 'pulselength'
solutions()
df = cf252
datatype = 'pulselength'
solutions()
df = na22
datatype = 'pulselength'
solutions()'''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_59030/2610534034.py in <module>
#       1 df = bi214
#       2 datatype = 'pulseArea_phd'
# ----> 3 solutions()
#       4 '''
#       5 df = po214
#
# /tmp/ipykernel_59030/2049309000.py in solutions()
#      20             rankedsolutions = []
#      21             for s in solutions:
# ---> 22                 rankedsolutions.append( (fitness(s[0],s[1]),s) )
#      23             rankedsolutions.sort()
#      24             rankedsolutions.reverse()
#
# /tmp/ipykernel_59030/2049309000.py in fitness(min, max)
#       1 def fitness(min,max):
# ----> 2     ans = cut_1D(min,max)
#       3
#       4     if ans == 0:
#       5         return 99999
#
# /tmp/ipykernel_59030/1608271949.py in cut_1D(min, max)
#       3     #print(min)
#       4     #print(max)
# ...
